# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 11 </b></center>
#
# <p>Name: Bhadra Mohitkumar Ajay</p>
#
# <p>Enrollment: 23010101605</p>
# <pre>

# %% [markdown]
# ## Step 1: Import Necessary Libraries
# complete the import statements below.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# ## Step 2: Load the Dataset
# Load the dataset (e.g., Iris dataset) or use your own.

# %%
data=load_iris()
X=data.data
y=data.target

# %% [markdown]
# ## Step 3: Preprocess the Data (Standardization)
# Standardize the dataset before applying PCA or LDA.

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %% [markdown]
# ## Step 4: Apply PCA
# Perform PCA and extract the principal components.

# %%
pca=PCA(n_components=2)
X_pca=pca.fit_transform(X_scaled)

# %%
X_pca
# Out:
# array([[-2.26470281,  0.4800266 ],
#        [-2.08096115, -0.67413356],
#        [-2.36422905, -0.34190802],
#        [-2.29938422, -0.59739451],
#        [-2.38984217,  0.64683538],
#        [-2.07563095,  1.48917752],
#        [-2.44402884,  0.0476442 ],
#        [-2.23284716,  0.22314807],
#        [-2.33464048, -1.11532768],
#        [-2.18432817, -0.46901356],
#        [-2.1663101 ,  1.04369065],
#        [-2.32613087,  0.13307834],
#        [-2.2184509 , -0.72867617],
#        [-2.6331007 , -0.96150673],
#        [-2.1987406 ,  1.86005711],
#        [-2.26221453,  2.68628449],
#        [-2.2075877 ,  1.48360936],
#        [-2.19034951,  0.48883832],
#        [-1.898572  ,  1.40501879],
#        [-2.34336905,  1.12784938],
#        [-1.914323  ,  0.40885571],
#        [-2.20701284,  0.92412143],
#        [-2.7743447 ,  0.45834367],
#        [-1.81866953,  0.08555853],
#        [-2.22716331,  0.13725446],
#        [-1.95184633, -0.62561859],
#        [-2.05115137,  0.24216355],
# ...

# %% [markdown]
# ## Step 5: Apply LDA
# Perform LDA and extract the discriminant components.

# %%
lda=LDA(n_components=2)
X_lda=lda.fit_transform(X_scaled,y)

# %%
X_lda
# Out:
# array([[ 8.06179978e+00, -3.00420621e-01],
#        [ 7.12868772e+00,  7.86660426e-01],
#        [ 7.48982797e+00,  2.65384488e-01],
#        [ 6.81320057e+00,  6.70631068e-01],
#        [ 8.13230933e+00, -5.14462530e-01],
#        [ 7.70194674e+00, -1.46172097e+00],
#        [ 7.21261762e+00, -3.55836209e-01],
#        [ 7.60529355e+00,  1.16338380e-02],
#        [ 6.56055159e+00,  1.01516362e+00],
#        [ 7.34305989e+00,  9.47319209e-01],
#        [ 8.39738652e+00, -6.47363392e-01],
#        [ 7.21929685e+00,  1.09646389e-01],
#        [ 7.32679599e+00,  1.07298943e+00],
#        [ 7.57247066e+00,  8.05464137e-01],
#        [ 9.84984300e+00, -1.58593698e+00],
#        [ 9.15823890e+00, -2.73759647e+00],
#        [ 8.58243141e+00, -1.83448945e+00],
#        [ 7.78075375e+00, -5.84339407e-01],
#        [ 8.07835876e+00, -9.68580703e-01],
#        [ 8.02097451e+00, -1.14050366e+00],
#        [ 7.49680227e+00,  1.88377220e-01],
#        [ 7.58648117e+00, -1.20797032e+00],
# ...

# %% [markdown]
# ## Step 6: Visualization
# Visualize PCA and LDA results using scatter plots.

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y,cmap='rainbow')
plt.title("PCA")
plt.show()

plt.scatter(X_lda[:,0],X_lda[:,1],c=y,cmap='viridis')
plt.title("LDA")
plt.show()

# %% [markdown]
# ## Train the model using above data

# %%
x_pca_train,x_pca_test,y_pca_train,y_pca_test=train_test_split(X_pca,y,test_size=0.3,random_state=42)
model=DecisionTreeClassifier()
model.fit(x_pca_train,y_pca_train)
model_predict=model.predict(x_pca_test)

print(f"Decision Tree Accuracy : {accuracy_score(y_pca_test,model_predict)}")
cm=confusion_matrix(y_pca_test,model_predict)
print(classification_report(y_pca_test,model_predict))


print("Confusion Matrix", cm)
# Out:
# Decision Tree Accuracy : 0.9555555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.92      0.92      0.92        13
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
#
# Confusion Matrix [[19  0  0]
#  [ 0 12  1]
#  [ 0  1 12]]

# %%
plt.figure(figsize=(100,100))
plot_tree(model)
# Out:
# [Text(0.47058823529411764, 0.9285714285714286, 'x[0] <= -1.153\ngini = 0.664\nsamples = 105\nvalue = [31, 37, 37]'),
#  Text(0.4117647058823529, 0.7857142857142857, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.4411764705882353, 0.8571428571428572, 'True  '),
#  Text(0.5294117647058824, 0.7857142857142857, 'x[0] <= 1.108\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]'),
#  Text(0.5, 0.8571428571428572, '  False'),
#  Text(0.29411764705882354, 0.6428571428571429, 'x[0] <= 0.9\ngini = 0.188\nsamples = 38\nvalue = [0, 34, 4]'),
#  Text(0.17647058823529413, 0.5, 'x[1] <= -1.553\ngini = 0.064\nsamples = 30\nvalue = [0, 29, 1]'),
#  Text(0.11764705882352941, 0.35714285714285715, 'x[1] <= -1.562\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 1]'),
#  Text(0.058823529411764705, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.17647058823529413, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
# ...

# %% [markdown]
# ## Step 7: Feature Selection using Filter Methods
# In this section, you will apply different filter methods such as:
# - **Pearson Correlation Coefficient**
# - **Chi-Square Test**
# - **Variance Thresholding**

# %% [markdown]
# ### 8.1 Pearson Correlation Coefficient
# Calculate the correlation between features and the target variable.

# %%
import seaborn as sns

correlation_matrix=np.corrcoef(X_scaled.T)
sns.heatmap(correlation_matrix,annot=True)
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# ### 8.2 Chi-Square Test
# Use the Chi-Square test to determine the relationship between features and the target variable.

# %%
from sklearn.feature_selection import chi2,SelectKBest


feature_names=data.feature_names

selector=SelectKBest(score_func=chi2,k=4)
X_new=selector.fit_transform(X,y)

chi_scores_df=pd.DataFrame({'Feature':feature_names,'Chi2 Score':selector.scores_})
print(chi_scores_df.sort_values(by="Chi2 Score",ascending=False))
# Out:
#              Feature  Chi2 Score
# 2  petal length (cm)  116.312613
# 3   petal width (cm)   67.048360
# 0  sepal length (cm)   10.817821
# 1   sepal width (cm)    3.710728

# %% [markdown]
# ### 8.3 Variance Thresholding
# Remove features with low variance as they may not be useful for predictions.

# %%
from sklearn.feature_selection import VarianceThreshold

variance_threshold = VarianceThreshold(threshold=0.01)
var_selected = variance_threshold.fit_transform(data_standardized)
# Out:
# Selected features using Variance Thresholding: Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
selected_features_var = data_standardized.columns[variance_threshold.get_support()]
print("Selected features using Variance Thresholding:", selected_features_var)

# %% [markdown]
# ## Step 9: Feature Selection using Wrapper Methods
# Wrapper methods evaluate feature subsets based on model performance.
# In this section, we will use:
# - **Recursive Feature Elimination (RFE)**
# - **Sequential Feature Selection (SFS)**

# %% [markdown]
# ### 9.1 Recursive Feature Elimination (RFE)
# RFE removes the least important features iteratively until the optimal subset is reached.

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector=VarianceThreshold(threshold=1.0)
X_selected=selector.fit_transform(X_scaled)
print("Selected Features Shape : ",X_selected.shape)
# Out:
# Selected Features Shape :  (150, 1)

# %% [markdown]
# ### 9.2 Sequential Feature Selection (SFS)
# SFS iteratively selects the best-performing features by adding or removing them.

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier()
rfe=RFE(rf_model,n_features_to_select=2)
X_rfe=rfe.fit_transform(X_scaled,y)
print(f"Selected Feature Shape : {X_rfe.shape}")
# Out:
# Selected Feature Shape : (150, 2)

# %%
print(X_rfe)
# Out:
# [[-1.34022653e+00 -1.31544430e+00]
#  [-1.34022653e+00 -1.31544430e+00]
#  [-1.39706395e+00 -1.31544430e+00]
#  [-1.28338910e+00 -1.31544430e+00]
#  [-1.34022653e+00 -1.31544430e+00]
#  [-1.16971425e+00 -1.05217993e+00]
#  [-1.34022653e+00 -1.18381211e+00]
#  [-1.28338910e+00 -1.31544430e+00]
#  [-1.34022653e+00 -1.31544430e+00]
#  [-1.28338910e+00 -1.44707648e+00]
#  [-1.28338910e+00 -1.31544430e+00]
#  [-1.22655167e+00 -1.31544430e+00]
#  [-1.34022653e+00 -1.44707648e+00]
#  [-1.51073881e+00 -1.44707648e+00]
#  [-1.45390138e+00 -1.31544430e+00]
#  [-1.28338910e+00 -1.05217993e+00]
#  [-1.39706395e+00 -1.05217993e+00]
#  [-1.34022653e+00 -1.18381211e+00]
#  [-1.16971425e+00 -1.18381211e+00]
#  [-1.28338910e+00 -1.18381211e+00]
#  [-1.16971425e+00 -1.31544430e+00]
#  [-1.28338910e+00 -1.05217993e+00]
#  [-1.56757623e+00 -1.31544430e+00]
#  [-1.16971425e+00 -9.20547742e-01]
#  [-1.05603939e+00 -1.31544430e+00]
#  [-1.22655167e+00 -1.31544430e+00]
#  [-1.22655167e+00 -1.05217993e+00]
# ...

# %% [markdown]
# ## Step 10: Applying PCA on Digits Dataset
# In this section, we will apply PCA on the `load_digits` dataset, which consists of handwritten digit images, and visualize its effect.

# %% [markdown]
# ### 10.1 Load and Visualize the Digits Dataset
# We will load the dataset and visualize some sample images.

# %%
from sklearn.datasets import load_digits

digits=load_digits()
x_digits=digits.data
y_digits=digits.target

fig,axes=plt.subplots(2,5,figsize=(5,2))
for i,ax in enumerate(axes.flat):
    ax.imshow(digits.images[i],cmap='gray')
    ax.set_title(f'Label : {digits.target[i]}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10.2 Apply PCA and Reduce Dimensions
# We will reduce the dataset to 2 principal components and visualize the transformed data.

# %%
pca_digits=PCA(n_components=2)
X_pca_digits=pca_digits.fit_transform(x_digits)

plt.scatter(X_pca_digits[:,0],X_pca_digits[:,1],c=y_digits,cmap='rainbow',alpha=0.6)
plt.colorbar(label='Digit Label')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on digits Dataset')
plt.show()
